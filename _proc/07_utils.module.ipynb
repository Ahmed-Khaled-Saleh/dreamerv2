# %% [raw]
# ---
# description: Default description (change me)
# output-file: utils.module.html
# title: Default Title (change me)
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(get_parameters)
# Out:
# ---
#
# ### get_parameters
#
# >      get_parameters (modules:Iterable[torch.nn.modules.module.Module])
#
# *Given a list of torch modules, returns a list of their parameters.
# :param modules: iterable of modules
# :returns: a list of parameters*

# %%
#| echo: false
#| output: asis
show_doc(FreezeParameters)
# Out:
# ---
#
# ### FreezeParameters
#
# >      FreezeParameters (modules:Iterable[torch.nn.modules.module.Module])
#
# *Context manager to locally freeze gradients.
# In some cases with can speed up computation because gradients aren't calculated for these listed modules.
# example:
# ```
# with FreezeParameters([module]):
#     output_tensor = module(input_tensor)
# ```
# :param modules: iterable of modules. used to call .parameters() to freeze gradients.*
