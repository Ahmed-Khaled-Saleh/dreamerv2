# %% [raw]
# ---
# description: Default description (change me)
# output-file: utils.buffer.html
# title: Default Title (change me)
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(TransitionBuffer)
# Out:
# ---
#
# ### TransitionBuffer
#
# >      TransitionBuffer (capacity, obs_shape:Tuple[int], action_size:int,
# >                        seq_len:int, batch_size:int, obs_type=<class
# >                        'numpy.float32'>, action_type=<class 'numpy.float32'>)
#
# *Initialize self.  See help(type(self)) for accurate signature.*

# %%
#| echo: false
#| output: asis
show_doc(EpisodicBuffer)
# Out:
# ---
#
# ### EpisodicBuffer
#
# >      EpisodicBuffer (total_episodes, obs_shape:Tuple[int], action_size:int,
# >                      seq_len:int, batch_size:int, obs_type=<class
# >                      'numpy.float32'>, action_type=<class 'numpy.float32'>)
#
# *:params total_episodes: maximum no of episodes capacity*

# %%
#| echo: false
#| output: asis
show_doc(FluidEpisodicBuffer)
# Out:
# ---
#
# ### FluidEpisodicBuffer
#
# >      FluidEpisodicBuffer (total_episodes:int, obs_shape:Tuple[int],
# >                           action_size:int, seq_len:int, batch_size:int,
# >                           minimum_episode_len:Optional[int]=1,
# >                           obs_type:Optional[numpy.dtype]=<class
# >                           'numpy.uint8'>,
# >                           action_type:Optional[numpy.dtype]=<class
# >                           'numpy.float32'>, incr_len:Optional[int]=5)
#
# *:params total_episodes:*
