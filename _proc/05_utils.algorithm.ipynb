# %% [raw]
# ---
# description: Default description (change me)
# output-file: utils.algorithm.html
# title: Default Title (change me)
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(compute_return)
# Out:
# ---
#
# ### compute_return
#
# >      compute_return (reward:torch.Tensor, value:torch.Tensor,
# >                      discount:torch.Tensor, bootstrap:torch.Tensor,
# >                      lambda_:float)
#
# *Compute the discounted reward for a batch of data.
# reward, value, and discount are all shape [horizon - 1, batch, 1] (last element is cut off)
# Bootstrap is [batch, 1]*
