# %% [raw]
# ---
# description: Default description (change me)
# output-file: training.config.html
# title: Default Title (change me)
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(MinAtarConfig)
# Out:
# ---
#
# ### MinAtarConfig
#
# >      MinAtarConfig (env:str, obs_shape:Tuple, action_size:int,
# >                     pixel:bool=True, action_repeat:int=1,
# >                     capacity:int=1000000, obs_dtype:numpy.dtype=<class
# >                     'numpy.uint8'>, action_dtype:numpy.dtype=<class
# >                     'numpy.float32'>, train_steps:int=5000000,
# >                     train_every:int=50, collect_intervals:int=5,
# >                     batch_size:int=50, seq_len:int=50, eval_episode:int=4,
# >                     eval_render:bool=True, save_every:int=100000,
# >                     seed_steps:int=4000, model_dir:int='results',
# >                     gif_dir:int='results', rssm_type:str='discrete',
# >                     embedding_size:int=200, rssm_node_size:int=200,
# >                     rssm_info:Dict=<factory>, grad_clip:float=100.0,
# >                     discount_:float=0.99, lambda_:float=0.95, horizon:int=10,
# ...

# %%
#| echo: false
#| output: asis
show_doc(MiniGridConfig)
# Out:
# ---
#
# ### MiniGridConfig
#
# >      MiniGridConfig (env:str, obs_shape:Tuple, action_size:int,
# >                      pixel:bool=True, action_repeat:int=1,
# >                      time_limit:int=1000, capacity:int=1000000,
# >                      obs_dtype:numpy.dtype=<class 'numpy.uint8'>,
# >                      action_dtype:numpy.dtype=<class 'numpy.float32'>,
# >                      train_steps:int=1000000, train_every:int=5,
# >                      collect_intervals:int=5, batch_size:int=50,
# >                      seq_len:int=8, eval_episode:int=5,
# >                      eval_render:bool=False, save_every:int=50000,
# >                      seed_episodes:int=5, model_dir:int='results',
# >                      gif_dir:int='results', rssm_type:str='discrete',
# >                      embedding_size:int=100, rssm_node_size:int=100,
# >                      rssm_info:Dict=<factory>, grad_clip:float=100.0,
# ...
