# %% [raw]
# ---
# description: Default description (change me)
# output-file: utils.wrapper.html
# title: Default Title (change me)
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(GymMinAtar)
# Out:
# ---
#
# ### GymMinAtar
#
# >      GymMinAtar (env_name, display_time=50)
#
# *The main OpenAI Gym class. It encapsulates an environment with
# arbitrary behind-the-scenes dynamics. An environment can be
# partially or fully observed.
#
# The main API methods that users of this class need to know are:
#
#     step
#     reset
#     render
#     close
#     seed
#
# And set the following attributes:
#
#     action_space: The Space object corresponding to valid actions
#     observation_space: The Space object corresponding to valid observations
#     reward_range: A tuple corresponding to the min and max possible rewards
#
# Note: a default reward range set to [-inf,+inf] already exists. Set it if you want a narrower range.
#
# The methods are accessed publicly as "step", "reset", etc...*

# %%
#| echo: false
#| output: asis
show_doc(breakoutPOMDP)
# Out:
# ---
#
# ### breakoutPOMDP
#
# >      breakoutPOMDP (env)
#
# *Wraps the environment to allow a modular transformation.
#
# This class is the base class for all wrappers. The subclass could override
# some methods to change the behavior of the original environment without touching the
# original code.
#
# .. note::
#
#     Don't forget to call ``super().__init__(env)`` if the subclass overrides :meth:`__init__`.*

# %%
#| echo: false
#| output: asis
show_doc(asterixPOMDP)
# Out:
# ---
#
# ### asterixPOMDP
#
# >      asterixPOMDP (env)
#
# *index 2 (trail) is removed, which gives ball's direction*

# %%
#| echo: false
#| output: asis
show_doc(freewayPOMDP)
# Out:
# ---
#
# ### freewayPOMDP
#
# >      freewayPOMDP (env)
#
# *index 2-6 (trail and speed) are removed, which gives cars' speed and direction*

# %%
#| echo: false
#| output: asis
show_doc(space_invadersPOMDP)
# Out:
# ---
#
# ### space_invadersPOMDP
#
# >      space_invadersPOMDP (env)
#
# *index 2-3 (trail) are removed, which gives aliens' direction*

# %%
#| echo: false
#| output: asis
show_doc(seaquestPOMDP)
# Out:
# ---
#
# ### seaquestPOMDP
#
# >      seaquestPOMDP (env)
#
# *index 3 (trail) is removed, which gives enemy and driver's direction*

# %%
#| echo: false
#| output: asis
show_doc(ActionRepeat)
# Out:
# ---
#
# ### ActionRepeat
#
# >      ActionRepeat (env, repeat=1)
#
# *Wraps the environment to allow a modular transformation.
#
# This class is the base class for all wrappers. The subclass could override
# some methods to change the behavior of the original environment without touching the
# original code.
#
# .. note::
#
#     Don't forget to call ``super().__init__(env)`` if the subclass overrides :meth:`__init__`.*

# %%
#| echo: false
#| output: asis
show_doc(TimeLimit)
# Out:
# ---
#
# ### TimeLimit
#
# >      TimeLimit (env, duration)
#
# *Wraps the environment to allow a modular transformation.
#
# This class is the base class for all wrappers. The subclass could override
# some methods to change the behavior of the original environment without touching the
# original code.
#
# .. note::
#
#     Don't forget to call ``super().__init__(env)`` if the subclass overrides :meth:`__init__`.*

# %%
#| echo: false
#| output: asis
show_doc(OneHotAction)
# Out:
# ---
#
# ### OneHotAction
#
# >      OneHotAction (env)
#
# *Wraps the environment to allow a modular transformation.
#
# This class is the base class for all wrappers. The subclass could override
# some methods to change the behavior of the original environment without touching the
# original code.
#
# .. note::
#
#     Don't forget to call ``super().__init__(env)`` if the subclass overrides :meth:`__init__`.*
