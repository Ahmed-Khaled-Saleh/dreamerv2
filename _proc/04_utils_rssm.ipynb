# %% [raw]
# ---
# description: Various utilities for the RSSM.
# output-file: utils_rssm.html
# title: Utils for RSSM
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(batch_to_seq)
# Out:
# ---
#
# ### batch_to_seq
#
# >      batch_to_seq (batch_data, batch_size, seq_len)
#
# *converts a single batch of size L*B to a sequence of length L and batch_size B*

# %%
#| echo: false
#| output: asis
show_doc(seq_to_batch)
# Out:
# ---
#
# ### seq_to_batch
#
# >      seq_to_batch (sequence_data, batch_size, seq_len)
#
# *converts a sequence of length L and batch_size B to a single batch of size L*B*

# %%
#| echo: false
#| output: asis
show_doc(RSSMUtils)
# Out:
# ---
#
# ### RSSMUtils
#
# >      RSSMUtils (rssm_type, info)
#
# *utility functions for dealing with rssm states*

# %%
#| echo: false
#| output: asis
show_doc(RSSMUtils.rssm_seq_to_batch)
# Out:
# ---
#
# ### RSSMUtils.rssm_seq_to_batch
#
# >      RSSMUtils.rssm_seq_to_batch (rssm_state, batch_size, seq_len)

# %%
#| echo: false
#| output: asis
show_doc(RSSMUtils.rssm_batch_to_seq)
# Out:
# ---
#
# ### RSSMUtils.rssm_batch_to_seq
#
# >      RSSMUtils.rssm_batch_to_seq (rssm_state, batch_size, seq_len)

# %%
#| echo: false
#| output: asis
show_doc(RSSMUtils.get_dist)
# Out:
# ---
#
# ### RSSMUtils.get_dist
#
# >      RSSMUtils.get_dist (rssm_state)

# %%
#| echo: false
#| output: asis
show_doc(RSSMUtils.get_stoch_state)
# Out:
# ---
#
# ### RSSMUtils.get_stoch_state
#
# >      RSSMUtils.get_stoch_state (stats)

# %%
#| echo: false
#| output: asis
show_doc(RSSMUtils.rssm_stack_states)
# Out:
# ---
#
# ### RSSMUtils.rssm_stack_states
#
# >      RSSMUtils.rssm_stack_states (rssm_states, dim)

# %%
#| echo: false
#| output: asis
show_doc(RSSMUtils.get_model_state)
# Out:
# ---
#
# ### RSSMUtils.get_model_state
#
# >      RSSMUtils.get_model_state (rssm_state)

# %%
#| echo: false
#| output: asis
show_doc(RSSMUtils.rssm_detach)
# Out:
# ---
#
# ### RSSMUtils.rssm_detach
#
# >      RSSMUtils.rssm_detach (rssm_state)
